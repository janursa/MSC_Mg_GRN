# %% [markdown]
# <div class="alert alert-info">
#
# # Overview
#
# In this section, we conduct model selection as follows:
# - Enquiry STRING for the known protein functional relationships
# - Create baseline random models
# - Calculate model selection scores for different models
# - Plot the early precision ratio as violinplot for all models
# - Select the best models for short and long term responses
# - Runs uncertainity analysis to evaluate if DE proteins are significantly better than reandom regulators
# - Plot the results of previous step using violinplot
#
# </div>

# %%
# get the functional relationships from string
# %run ../proteomics_MSC/model_selection/string_enquiry.py
# Out:
# output -> C:\Users\nourisa\Documents\testProjs\completed\proteomics_MSC_Mg_model\proteomics_MSC\../results/model_selection/string\links_early_MinProb.csv
# output -> C:\Users\nourisa\Documents\testProjs\completed\proteomics_MSC_Mg_model\proteomics_MSC\../results/model_selection/string\links_early_KNN.csv
# output -> C:\Users\nourisa\Documents\testProjs\completed\proteomics_MSC_Mg_model\proteomics_MSC\../results/model_selection/string\links_late_MinProb.csv
# output -> C:\Users\nourisa\Documents\testProjs\completed\proteomics_MSC_Mg_model\proteomics_MSC\../results/model_selection/string\links_late_KNN.csv

# %%
# Creates random baseline models using inferred links and calculate ep for random models
# %run ../proteomics_MSC/model_selection/create_baseline_models.py
# Out:
# Progress for early_MinProb: 100%|██████████| 1000/1000 [00:09<00:00, 102.21it/s]
# output -> C:\Users\nourisa\Documents\testProjs\completed\proteomics_MSC_Mg_model\proteomics_MSC\..\results\model_selection\baseline_models/ep_scores_early_MinProb.csv
# output -> C:\Users\nourisa\Documents\testProjs\completed\proteomics_MSC_Mg_model\proteomics_MSC\..\results\model_selection\baseline_models/ep_scores_series_early_MinProb.csv
# Progress for early_KNN: 100%|██████████| 1000/1000 [00:11<00:00, 83.83it/s]
# output -> C:\Users\nourisa\Documents\testProjs\completed\proteomics_MSC_Mg_model\proteomics_MSC\..\results\model_selection\baseline_models/ep_scores_early_KNN.csv
# output -> C:\Users\nourisa\Documents\testProjs\completed\proteomics_MSC_Mg_model\proteomics_MSC\..\results\model_selection\baseline_models/ep_scores_series_early_KNN.csv
# Progress for late_MinProb: 100%|██████████| 1000/1000 [00:10<00:00, 97.95it/s]
# ...

# %%
# Calculates model selections scores of early precision rate, sig flags, etc.
# %run ../proteomics_MSC/model_selection/calculate_scores.py
# Out:
# mean:  17.39780487804878 max:  35.36585365853658
# mean:  17.46297872340425 max:  34.8936170212766
# mean:  17.20159090909091 max:  34.77272727272727
# mean:  17.52573529411765 max:  29.852941176470587

# %%
# Violin plot for all models
# %run ../proteomics_MSC/model_selection/violin_plot.py
# Out:
# output -> C:\Users\nourisa\Documents\testProjs\completed\proteomics_MSC_Mg_model\proteomics_MSC\../results/model_selection\violinplot.png

# %%
# Select best models for short-term and long-term phases by filtering based on R2 score, sig_flag and using epr score
# %run ../proteomics_MSC/model_selection/model_selection.py
# Out:
# early_MinProb_portia -> ep scores: 22.4390243902439
# late_KNN_portia -> ep scores: 27.205882352941178

# %%
# evaluate random regulators vs DE regulators
# %run ../proteomics_MSC/random_regulators/calculate_random_scores.py

# %%
# plot the scores of the random regulators vs DE regulators
# %run ../proteomics_MSC/random_regulators/violin_plot.py
